# %%
from PIL import Image, ImageStat

img = Image.open('puppy.jpg')
stat = ImageStat.Stat(im)
print(stat.stddev)
plt.imshow(img)
# Out:
# [56.55859725177362, 54.488844625011986, 51.7711188157862]

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('cocktail.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
np.average(img)
# Out:
# 104.84676727430555

# %%
from PIL import Image,ImageStat
import matplotlib.pyplot as plt
im=Image.open('cocktail.jpg')
plt.imshow(im)
plt.show()
stat=ImageStat.Stat(im)
print(stat.stddev)
# Out:
# [56.55859725177362, 54.488844625011986, 51.7711188157862]

# %%
# example of pixel normalization
from numpy import asarray
from PIL import Image
# load image
image = Image.open('cougar.jpg')
pixels = asarray(image)
# confirm pixel range is 0-255
#print('Data Type: %s' % pixels.dtype)
print('Min: %.3f, Max: %.3f' % (pixels.min(), pixels.max()))
# convert from integers to floats
pixels = pixels.astype('float32')
# normalize to the range 0-1
pixels /= 255.0
# confirm the normalization
print('Min: %.3f, Max: %.3f' % (pixels.min(), pixels.max()))
plt.imshow(image)
# Out:
# Min: 0.000, Max: 255.000
# Min: 0.000, Max: 1.000

# %%
# example of pixel normalization
from numpy import asarray
from PIL import Image
# load image
image = Image.open('cougar.jpg')
pixels = asarray(image)
# confirm pixel range is 0-255
#print('Data Type: %s' % pixels.dtype)
print('Min: %.3f, Max: %.3f' % (pixels.min(), pixels.max()))
# convert from integers to floats
pixels = pixels.astype('float32')
# normalize to the range 0-1
pixels /= 255.0
# confirm the normalization
print('Min: %.3f, Max: %.3f' % (pixels.min(), pixels.max()))
# Out:
# Min: 0.000, Max: 255.000
# Min: 0.000, Max: 1.000

# %%
#average
import imageio
import matplotlib.pyplot as plt
img=imageio.imread("cougar.jpg")
plt.imshow(img)
np.average(img)
# Out:
# 144.15512138310186

# %%
#standard deviation
from PIL import Image,ImageStat
import matplotlib.pyplot as plt
im=Image.open('cougar.jpg')
plt.imshow(im)
plt.show()
stat=ImageStat.Stat(im)
print(stat.stddev)
# Out:
# [53.69851198263657, 51.40191910657747, 50.843328191103936]

# %%
#Max
import imageio
import numpy as np
import matplotlib.pyplot as plt
img=imageio.imread('cougar.jpg' )
plt.imshow(img)
plt.show()
max_channels = np.amax([np.amax(img[:,:,0]), np.amax(img[:,:,1]),np.amax(img[:,:,2])])

print(max_channels)
# Out:
# 255

# %%
#Min
import imageio
import numpy as np
import matplotlib.pyplot as plt
img=imageio.imread('cougar.jpg' )
plt.imshow(img)
plt.show()
min_channels = np.amin([np.min(img[:,:,0]), np.amin(img[:,:,1]),np.amin(img[:,:,2])])

print(min_channels)
# Out:
# 0
