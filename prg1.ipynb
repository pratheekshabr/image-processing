# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
img=cv2.imread('plant1.jfif',0)
cv2.imshow('plant1',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.image as mping
import matplotlib.pyplot as plt
img=mping.imread("plant1.jfif")
plt.imshow(img)

# %%
import cv2
from PIL import Image
img=Image.open("plant5.jpg")
img=img.rotate(180)
img.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import ImageColor
img1=ImageColor.getrgb("yellow")
print(img1)
img2=ImageColor.getrgb("red")
print(img2)
img3=ImageColor.getrgb("Pink")
print(img3)
# Out:
# (255, 255, 0)
# (255, 0, 0)
# (255, 192, 203)

# %%
from PIL import Image
img=Image.new('RGB',(200,400),(255,0,0))
img.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('plant5.jpg')
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.show()

# %%
from PIL  import Image
image=Image.open('plant5.jpg')
print("Filename:",image.filename)
print("Mode:",image.mode)
print("size:",image.size)
print("width:",image.width)
print("height:",image.height)
image.close()
# Out:
# Filename: plant5.jpg
# Mode: RGB
# size: (500, 477)
# width: 500
# height: 477
