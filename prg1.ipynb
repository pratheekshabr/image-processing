# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\user\anaconda3\lib\site-packages (from opencv-python) (1.20.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
img=cv2.imread('plant1.jfif',0)
cv2.imshow('plant1',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.image as mping
import matplotlib.pyplot as plt
img=mping.imread("plant1.jfif")
plt.imshow(img)

# %%
import cv2
from PIL import Image
img=Image open("plant5.jpg")
img=img.rotate(180)
img.show()
cv2.waitkey(0)
cv2.destroyAllWindows()
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_972/1403774218.py", line 3
#     img=Image open("plant5.jpg")
#               ^
# SyntaxError: invalid syntax

# %%
from PIL import Imagecolor
img1=ImageColor.getrgh("yellow")
print(img1)
img2=ImageColor.getrgh("red")
print(img2)
img3=ImageColor.getrgh("Pink")
print(img3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_972/1784258820.py in <module>
# ----> 1 from PIL import Imagecolor
#       2 img1=ImageColor.getrgh("yellow")
#       3 print(img1)
#       4 img2=ImageColor.getrgh("red")
#       5 print(img2)
#
# ImportError: cannot import name 'Imagecolor' from 'PIL' (C:\Users\User\anaconda3\lib\site-packages\PIL\__init__.py)

# %%
from PIL import Image
img=Image.new('rgb',(200,400),(255,255,0))
img.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_972/1269010965.py in <module>
#       1 from PIL import Image
# ----> 2 img=Image.new('rgb',(200,400),(255,255,0))
#       3 img.show()
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in new(mode, size, color)
#    2703         im.palette = ImagePalette.ImagePalette()
#    2704         color = im.palette.getcolor(color)
# -> 2705     return im._new(core.fill(mode, size, color))
#    2706
#    2707
#
# ValueError: unrecognized image mode

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
